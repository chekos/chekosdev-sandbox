# %% [markdown]
# # Vamos a sintetizar un conjunto de datos a partir del extract de spotify

# %%
from pathlib import Path 
import json

import pandas as pd
import altair as alt
import sidetable
import janitor
from rich import print

# %%
alt.data_transformers.disable_max_rows()
# Out:
# DataTransformerRegistry.enable('default')

# %%
mydata = Path(".").joinpath("MyData")

# %%
history = []
for file in mydata.glob("Streaming*.json"):
    with open(file, "r") as json_file:
        history.extend(json.load(json_file))

# %%
print(history[0])
# Out:
# {'endTime': '2021-12-28 00:00', 'artistName': 'Desert Niños', 'trackName': 'American Party', 'msPlayed': 274100}

# %%
data = pd.DataFrame(history).clean_names().rename(columns= {"artistname": "artist", "trackname": "track"})

# %%
data.shape
# Out:
# (10232, 4)

# %%
data.head()
# Out:
#             endtime        artist           track  msplayed
# 0  2021-12-28 00:00  Desert Niños  American Party    274100
# 1  2021-12-28 00:05  Desert Niños     Luz de Luna    279300
# 2  2021-12-28 00:09  Desert Niños           Kayak    245000
# 3  2021-12-28 00:13  Desert Niños         Calidad    201200
# 4  2021-12-28 00:16  Desert Niños           Lobos    197600

# %%
data.groupby(['artist', 'track']).count()
# Out:
#                                                            endtime  msplayed
# artist                               track
# A Tribe Called Quest                 Excursions                  1         1
# A$AP Ferg                            Plain Jane                  2         2
# A.C.O                                De Madrugada                8         8
#                                      El encendedor               1         1
# Ab-Soul                              D.R.U.G.S.                  4         4
# ...                                                            ...       ...
# sofia shizuko                        chichiriviche               7         7
# Ídolo: The Ballad of Chalino Sánchez 1. Death Note               2         2
#                                      1. La nota de muerte        1         1
# Ñengo El Quetzal                     El Rikis                    1         1
#                                      Plakka Plakka               1         1
#
# [1928 rows x 2 columns]

# %%
data.stb.freq(['artist', 'track'])
# Out:
#                     artist                  track  count   percent  \
# 0               La Plebada  Placoseo Como Se Debe    139  1.358483
# 1               La Plebada                  El R8    129  1.260751
# 2               La Plebada             La Galliza    124  1.211884
# 3          La Banda Baston           Lupe Esparza    110  1.075059
# 4               La Plebada                Del Año    106  1.035966
# ...                    ...                    ...    ...       ...
# 1923             Akapellah             Como Mario      1  0.009773
# 1924             Akapellah             Cielo Gris      1  0.009773
# 1925    Adn Maya Colectivo   Laayli' kuxa'ano'one      1  0.009773
# 1926                 A.C.O          El encendedor      1  0.009773
# 1927  A Tribe Called Quest             Excursions      1  0.009773
#
#       cumulative_count  cumulative_percent
# 0                  139            1.358483
# 1                  268            2.619234
# 2                  392            3.831118
# 3                  502            4.906177
# 4                  608            5.942142
# ...                ...                 ...
# 1923             10228           99.960907
# 1924             10229           99.970680
# 1925             10230           99.980453
# 1926             10231           99.990227
# 1927             10232          100.000000
#
# [1928 rows x 6 columns]

# %%
data.stb.freq(['artist'])
# Out:
#                    artist  count    percent  cumulative_count  \
# 0              La Plebada   1243  12.148163              1243
# 1         La Banda Baston   1096  10.711493              2339
# 2                   Fntxy    601   5.873729              2940
# 3            Desert Niños    405   3.958170              3345
# 4               Yoga Fire    389   3.801798              3734
# ..                    ...    ...        ...               ...
# 475      Althea And Donna      1   0.009773             10228
# 476   Alejandro Fernández      1   0.009773             10229
# 477        Al2 El Aldeano      1   0.009773             10230
# 478    Adn Maya Colectivo      1   0.009773             10231
# 479  A Tribe Called Quest      1   0.009773             10232
#
#      cumulative_percent
# 0             12.148163
# 1             22.859656
# 2             28.733385
# 3             32.691556
# 4             36.493354
# ..                  ...
# 475           99.960907
# 476           99.970680
# 477           99.980453
# 478           99.990227
# 479          100.000000
#
# [480 rows x 5 columns]

# %%
data.stb.missing()
# Out:
#           missing  total  percent
# endtime         0  10232      0.0
# artist          0  10232      0.0
# track           0  10232      0.0
# msplayed        0  10232      0.0

# %%
podcast_names = [
    "NO SKIPS with Jinx and Shea",
    "Just Break Up",
    "Normal Gossip",
    "Questlove Supreme",
    "El Flowcast", 
    "RADIOSUENARECIO!",
    "The Sum of Us",
    "Ídolo: The Ballad of Chalino Sánchez",
    "The Cipher",
    "La Cima",
    "Chats with Cat",
    "Dissect", 
    "The Latin Alternative",
    "LOUD",
    "Draws in Spanish |  Conversations with Latinx Visual Artists and Designers",
    "Mano a Mano",
    "Entiende Tu Mente",
    "Lo Que Ando Oyendo",
    "LobaLand: Wellness Experience",
    "California Love",
    "How to Save a Planet",
    "WILD",
]

# %%
mask_msplayed = data['msplayed'] >= 30_000 # 30 second
mask_podcasts = data['artist'].str.strip().isin(podcast_names)

# %%
data[mask_msplayed & ~mask_podcasts]['artist'].value_counts().tail(110)
# Out:
# Selena                   1
# Kase.O                   1
# Lupillo Rivera           1
# Kid Dee                  1
# Mime 871                 1
#                         ..
# Los Bunkers              1
# Los Amigos Invisibles    1
# Mœnia                    1
# Flor De Rap              1
# ROSE BEAT                1
# Name: artist, Length: 110, dtype: int64

# %%
podcast_data = data[mask_podcasts].copy()
data = data[mask_msplayed & ~mask_podcasts]

# %%
podcast_data
# Out:
#                endtime                       artist  \
# 122   2021-12-29 16:54                 El Flowcast
# 473   2022-01-07 03:12                 El Flowcast
# 474   2022-01-07 03:12                 El Flowcast
# 487   2022-01-07 14:57              California Love
# 546   2022-01-10 01:00  NO SKIPS with Jinx and Shea
# ...                ...                          ...
# 9155  2022-11-01 03:45                The Sum of Us
# 9703  2022-11-25 13:08            Entiende Tu Mente
# 9704  2022-11-25 13:19            Entiende Tu Mente
# 9767  2022-11-26 16:06            Entiende Tu Mente
# 9768  2022-11-26 16:45            Entiende Tu Mente
#
#                                                   track  msplayed
# 122                             Adán Cruz | Episodio 3     550591
# 473                             Eptos Uno | Episodio 13   3441293
# 474                            Miky Woodz | Episodio 14     32771
# 487                                            Prologue    433516
# 546      Mos Def: ‘Black on Both Sides’ | Vol. 2 Ep. 10    793356
# ...                                                 ...       ...
# 9155                           Lewiston, ME: A New Crop    530705
# 9703                     Ser "demasiado" racional | 225     30160
# 9704                     Ser "demasiado" racional | 225    530840
# 9767                     Ser "demasiado" racional | 225    731075
# 9768  Comenzar una relación sin perder tus espacios ...    737068
#
# [122 rows x 4 columns]

# %%
data.sort_values(by="msplayed", ascending = False).tail(50)
# Out:
#                 endtime                   artist  \
# 2675   2022-03-26 22:49               La Plebada
# 4407   2022-06-02 01:37          La Banda Baston
# 1570   2022-02-21 03:56            Mantequilloso
# 4033   2022-05-16 19:57                Bad Bunny
# 4317   2022-05-30 03:29                       Wk
# 2565   2022-03-25 03:05               La Plebada
# 1897   2022-03-05 17:48                   Aleman
# 5528   2022-07-15 14:54             Daddy Yankee
# 2983   2022-04-05 18:57               La Plebada
# 1037   2022-01-31 15:58                  Molotov
# 10161  2022-12-20 00:53                Phyzh Eye
# 5170   2022-06-27 15:48                Yoga Fire
# 852    2022-01-21 02:48            Mantequilloso
# 431    2022-01-05 07:11           Kendrick Lamar
# 840    2022-01-21 02:12               DJ Sonicko
# 3576   2022-04-28 14:32                Raaginder
# 5990   2022-07-24 22:31                    Fntxy
# 3054   2022-04-09 02:25            Fivio Foreign
# 3942   2022-05-13 16:20                Bad Bunny
# 4400   2022-06-01 23:27              Charles Ans
# 3029   2022-04-08 19:59              Charles Ans
# 4413   2022-06-02 01:54                  Molotov
# 10138  2022-12-17 02:16      Los Enanitos Verdes
# 859    2022-01-21 03:26                 Junior H
# 3624   2022-04-30 22:07                  J Dilla
# 4802   2022-06-09 01:18                Bad Bunny
# 10137  2022-12-17 02:15  Los Fabulosos Cadillacs
# 4765   2022-06-07 20:38           Kendrick Lamar
# 2265   2022-03-20 03:21               La Plebada
# 172    2021-12-30 03:23                Neto Peña
# 797    2022-01-20 04:39             Don Kalavera
# 4685   2022-06-05 03:47           Teeam Revolver
# 1715   2022-02-26 21:45               Faruz Feet
# 130    2021-12-29 21:42                Neto Peña
# 2528   2022-03-24 04:18                      MOF
# 549    2022-01-10 01:04                 Ozomatli
# 2732   2022-03-27 16:15          La Banda Baston
# 10173  2022-12-22 17:52                ROSE BEAT
# 8386   2022-09-30 14:51           Remik Gonzalez
# 5793   2022-07-20 00:21                West Gold
# 9930   2022-12-05 04:20                    Fntxy
# 9181   2022-11-04 00:46            Santa Fe Klan
# 5702   2022-07-18 02:22              Warmduscher
# 3999   2022-05-15 20:08                  Molotov
# 9039   2022-10-26 22:37               La Plebada
# 2507   2022-03-24 01:12               La Plebada
# 701    2022-01-15 17:22                Kinto Sol
# 9798   2022-11-29 00:38             Macz Morales
# 767    2022-01-17 22:40           Remik Gonzalez
# 7139   2022-08-26 18:35               Rich Vagos
#
#                                                    track  msplayed
# 2675                                         Por la Mala     32937
# 4407                               Roberto Gómez Bolaños     32883
# 1570                                             Espera.     32861
# 4033                                    Yo No Soy Celoso     32853
# 4317                                      Todo Está Bien     32848
# 2565                                         Por la Mala     32798
# 1897                                              Cabrón     32684
# 5528   Mix Rap 1: 30-30 / Mi Fanatico / Se Acelera el...     32566
# 2983                                         Bien Jalado     32504
# 1037   Más Vale Cholo - Desde El Palacio De Los Deportes     32391
# 10161                                         La Palabra     32220
# 5170                                          Encajuelao     32157
# 852                                               Vacío.     32106
# 431                                        Hood Politics     31997
# 840                                    Eptos Uno Session     31950
# 3576                                              Jungle     31950
# 5990                                       Todavía Duele     31901
# 3054                                        City of Gods     31861
# 3942                                               Tarot     31798
# 4400                              Sin Gafas, Sin Filtros     31764
# 3029                                          Veintipico     31637
# 4413                                         Here We Kum     31560
# 10138                                Mil Horas - En Vivo     31550
# 859                                       Mente Positiva     31509
# 3624                                          Workinonit     31497
# 4802                                 Después de la Playa     31486
# 10137             Siguiendo la Luna - Remasterizado 2008     31460
# 4765                                    The Heart Part 5     31341
# 2265                                             Del Año     31306
# 172                                               Tóxica     31213
# 797                                           Traficante     31190
# 4685                                             Soledad     31175
# 1715                                         Turbulencia     31021
# 130                                           No Aguanto     30976
# 2528                                    Puntos y Monedas     30974
# 549                                     Donde Se Fueron?     30942
# 2732                                           Haces Mal     30812
# 10173              Stayin' Alive VS 50 C Tik Tok - Remix     30698
# 8386                                    Me Voy Pa' fuera     30633
# 5793                 Bag of Weed (feat. iQlover & Robot)     30611
# 9930                                             Velorio     30542
# 9181                                       Debo Entender     30416
# 5702                                           Big Wilma     30373
# 3999   Agüela (Mi Abuela & The Magnificent Seven & Bu...     30336
# 9039                                          Alivianado     30229
# 2507                               Placoseo Como Se Debe     30210
# 701                                 A Todo Se Acostumbra     30197
# 9798                                   Lo Hice Diferente     30189
# 767                                        Odio el Drama     30042
# 7139                                               A 120     30000

# %%
alt.Chart(data).mark_bar().encode(
    x = alt.X("msplayed", bin = alt.Bin(maxbins=50)),
    y = alt.Y("count()"),
)
# Out:
# /Users/sergio/projects/chekosdev-sandbox/.venv/lib/python3.10/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.Chart(...)

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from dotenv import dotenv_values

config = dotenv_values("../.env")

client_id = config.get("SPOTIPY_CLIENT_ID", " ")
client_secret = config.get("SPOTIPY_CLIENT_SECRET", " ")

sp = spotipy.Spotify(
    client_credentials_manager=SpotifyClientCredentials(
        client_id=client_id, client_secret=client_secret
    )
)

# %%
def get_track_info(query: str, is_uri: bool = False):
    if not is_uri:
        search_result = sp.search(query, limit=1, type="track")
        if search_result["tracks"]["items"]:
            track_item = search_result["tracks"]["items"][0]
        else:
            return False
    else:
        track_item = sp.track(query)

# %% [markdown]
# ## Check if already in uniqueTracks

# %%
with open("minMetadataTracks.json", "r") as file:
    unique_tracks = json.load(file)

# %%
already_saved = pd.DataFrame(unique_tracks)
already_saved['saved'] = True
already_saved
# Out:
#                          artist                                 album  \
# 0                     Mike Diaz                                Renace
# 1    Mexican Institute Of Sound                         Méjico Máxico
# 2               Cartel De Santa                       Viejo Marihuano
# 3               El Perro Gamboa                               Núm3Ros
# 4               La Banda Baston                 Degeneración Nacional
# ..                          ...                                   ...
# 903               Santa Fe Klan                         Ojos Tumbados
# 904                   José José                           Reencuentro
# 905                     Gera MX                          Se Me Olvidó
# 906                    Bizarrap  Aleman: Bzrp Music Sessions, Vol. 15
# 907                  Rich Vagos                                   MVP
#
#                                     track  \
# 0                                Kintsugi
# 1                 Mirando a las muchachas
# 2                                    Leve
# 3                                 Núm3Ros
# 4                                  Cuando
# ..                                    ...
# 903                         Ojos Tumbados
# 904                   El Amar y el Querer
# 905                          Se Me Olvidó
# 906  Aleman: Bzrp Music Sessions, Vol. 15
# 907                                   MVP
#
#                                       uri  saved
# 0    spotify:track:00TPikzhlAO79taN4K8VDK   True
# 1    spotify:track:00Z3s0Xw7oE3fgTSZVjEFs   True
# 2    spotify:track:00jpfco62YfQj1BBYCCuKH   True
# 3    spotify:track:00qVP7ZX0UJqvqJrhZWgYq   True
# 4    spotify:track:00r6SXWE6lvfikdbsl6qSR   True
# ..                                    ...    ...
# 903  spotify:track:7uYFOLEhhmojSLTyVZ8r4O   True
# 904  spotify:track:7wUt1v2ddVqPayC8EKDp5P   True
# 905  spotify:track:7xLYLM5K6S1TwiSdfuhZQg   True
# 906  spotify:track:7xRWmHZ2wt3zDgM5mAL0JU   True
# 907  spotify:track:7xWky8i89MApbmAZ0wdecv   True
#
# [908 rows x 5 columns]

# %%
data.set_index(['artist', 'track']).join(already_saved.set_index(["artist", "track"]))
# Out:
#                                              endtime  msplayed  \
# artist               track
# A Tribe Called Quest Excursions     2022-01-28 21:59     41865
# A$AP Ferg            Plain Jane     2022-03-27 02:20    173600
#                      Plain Jane     2022-11-29 01:31    173600
# A.C.O                De Madrugada   2022-01-21 02:55    220757
#                      De Madrugada   2022-07-18 15:48    220757
# ...                                              ...       ...
# sofia shizuko        chichiriviche  2022-07-15 00:49    149000
#                      chichiriviche  2022-07-15 00:55    149000
#                      chichiriviche  2022-07-16 18:59     69525
#                      chichiriviche  2022-08-15 19:58    149000
# Ñengo El Quetzal     Plakka Plakka  2022-07-20 18:45    181054
#
#                                              album  \
# artist               track
# A Tribe Called Quest Excursions                NaN
# A$AP Ferg            Plain Jane     Still Striving
#                      Plain Jane     Still Striving
# A.C.O                De Madrugada     De Madrugada
#                      De Madrugada     De Madrugada
# ...                                            ...
# sofia shizuko        chichiriviche   chichiriviche
#                      chichiriviche   chichiriviche
#                      chichiriviche   chichiriviche
#                      chichiriviche   chichiriviche
# Ñengo El Quetzal     Plakka Plakka             NaN
#
#                                                                      uri saved
# artist               track
# A Tribe Called Quest Excursions                                      NaN   NaN
# A$AP Ferg            Plain Jane     spotify:track:4dVpf9jZjcORqGTLUaeYj9  True
#                      Plain Jane     spotify:track:4dVpf9jZjcORqGTLUaeYj9  True
# A.C.O                De Madrugada   spotify:track:280QqgbMrLeMs6B80mIPG2  True
#                      De Madrugada   spotify:track:280QqgbMrLeMs6B80mIPG2  True
# ...                                                                  ...   ...
# sofia shizuko        chichiriviche  spotify:track:7MNtRrUXrsQwR10o3lvgDP  True
#                      chichiriviche  spotify:track:7MNtRrUXrsQwR10o3lvgDP  True
#                      chichiriviche  spotify:track:7MNtRrUXrsQwR10o3lvgDP  True
#                      chichiriviche  spotify:track:7MNtRrUXrsQwR10o3lvgDP  True
# Ñengo El Quetzal     Plakka Plakka                                   NaN   NaN
#
# [9392 rows x 5 columns]

# %% [markdown]
# ## Before searching all of them, maybe we have them in my library

# %%
with open(mydata.joinpath("YourLibrary.json"), "r") as file:
    library = json.load(file)

# %%
library_tracks = pd.DataFrame(library['tracks']).clean_names()

# %%
library_tracks.shape
# Out:
# (1746, 4)

# %%
library_tracks.head(15)
# Out:
#              artist                                 album  \
# 0      Nanpa Básico                           Como Bolero
# 1        Geassassin                             Right Now
# 2           Robot95                               Bullets
# 3        Neto Reyno                               Nr Hits
# 4       Tame Impala                         The Slow Rush
# 5          Hordatoj                 Beat Tape (Volumen 1)
# 6             Akwid                KOMP 104.9 Radio Compa
# 7       Café Tacvba                   Avalancha de éxitos
# 8             Fntxy                                Hvbitö
# 9           Robot95                         Too Much Flow
# 10         Bizarrap  Mesita: Bzrp Music Sessions, Vol. 12
# 11  Primero Company               Quien Mas Que Los Ñeros
# 12         Calle 13                            MultiViral
# 13            Fntxy                                Hvbitö
# 14              Dee                           Ojo de Gato
#
#                                       track  \
# 0                               Como Bolero
# 1                                 Right Now
# 2                                   Bullets
# 3                            Vida Callejera
# 4                                Borderline
# 5                                    C.u.e.
# 6                                Mi Afición
# 7                   Como te extraño mi amor
# 8                                       K Y
# 9                             Too Much Flow
# 10     Mesita: Bzrp Music Sessions, Vol. 12
# 11                                La Maleta
# 12  Ojos Color Sol (feat. Silvio Rodríguez)
# 13                                      K Y
# 14                              Ojo de Gato
#
#                                      uri
# 0   spotify:track:7pOBTfz9EOi9Yb64cOI6kv
# 1   spotify:track:1TqEsVQvnvs2H9kg4HkqQG
# 2   spotify:track:36i3GBIGaw0i1Gv6Kz6EPM
# 3   spotify:track:0N7XU51NdMaXgdq8h6iweg
# 4   spotify:track:5hM5arv9KDbCHS0k9uqwjr
# 5   spotify:track:1VudAJHMGsEYjgI4ltjLKx
# 6   spotify:track:2E36sO4oJvuTmhCt1ImjNB
# 7   spotify:track:6hFHsQWB7HdVrSe7efRR82
# 8   spotify:track:4iCgDMx1PEFrulIOgt3H3C
# 9   spotify:track:2ZBlDOQlq043eg34LwW54c
# 10  spotify:track:3HxP2g1l2jc9r1QgrA3dmf
# 11  spotify:track:5MUpnYt6MLXXlUxJkwDeM6
# 12  spotify:track:1RIhd7jjWDQwSKsbxxGArN
# 13  spotify:track:7sD6GAFoQMiABHx7jnvJZ8
# 14  spotify:track:6VQLfp8xkgkVNeLuSGTur7

# %%
tracks_uris = library_tracks.set_index(["artist", "album", "track"]).join(already_saved.set_index(["artist", "album", "track"]), rsuffix = "_saved", how = "outer").reset_index()
tracks_uris
# Out:
#                 artist                   album  \
# 0                 2Pac          All Eyez On Me
# 1                 2Pac          All Eyez On Me
# 2              50 Cent  Get Rich Or Die Tryin'
# 3            A$AP Ferg          Still Striving
# 4                A.C.O              Buscándote
# ...                ...                     ...
# 2066     sofia shizuko           chichiriviche
# 2067     Águila Sativa            Low Rider 64
# 2068  Ñengo El Quetzal                El Rikis
# 2069  Ñengo El Quetzal           Plakka Plakka
# 2070  Ñengo El Quetzal       Vengo de la Calle
#
#                                           track  \
# 0                          Ambitionz Az A Ridah
# 1     Only God Can Judge Me (ft. Rappin' 4-Tay)
# 2                             Patiently Waiting
# 3                                    Plain Jane
# 4                                    Buscándote
# ...                                         ...
# 2066                              chichiriviche
# 2067                               Low Rider 64
# 2068                                   El Rikis
# 2069                              Plakka Plakka
# 2070                          Vengo de la Calle
#
#                                        uri  \
# 0     spotify:track:20fBuVybkHgjF6vNhSMROD
# 1     spotify:track:2Z6I3youZAlfRvsyzJAGQA
# 2     spotify:track:3ORfa5ilEthp2U0TRcv7kv
# 3     spotify:track:4dVpf9jZjcORqGTLUaeYj9
# 4     spotify:track:5Qh1noyTdOz7d3GNTwwqJP
# ...                                    ...
# 2066  spotify:track:7MNtRrUXrsQwR10o3lvgDP
# 2067  spotify:track:7oCTo2ktHD7mX2knemZohF
# 2068  spotify:track:2VLpj3su9MbHqMWtxEqZhx
# 2069  spotify:track:1jzhpaWxMF1x4UtHrrERQW
# 2070  spotify:track:2UKfYR96zQkzHXwSbfyGDC
#
#                                  uri_saved saved
# 0                                      NaN   NaN
# 1                                      NaN   NaN
# 2                                      NaN   NaN
# 3     spotify:track:4dVpf9jZjcORqGTLUaeYj9  True
# 4                                      NaN   NaN
# ...                                    ...   ...
# 2066  spotify:track:7MNtRrUXrsQwR10o3lvgDP  True
# 2067                                   NaN   NaN
# 2068                                   NaN   NaN
# 2069                                   NaN   NaN
# 2070                                   NaN   NaN
#
# [2071 rows x 6 columns]

# %%
tracks_uris['track_uri'] = tracks_uris['uri_saved'].combine_first(tracks_uris['uri'])
tracks_uris = tracks_uris.drop(columns=["uri", "uri_saved"]).rename(columns = {"track_uri": "uri"})
tracks_uris['saved'] = tracks_uris['saved'].fillna(False)
tracks_uris = tracks_uris.drop_duplicates()
tracks_uris
# Out:
#                 artist                   album  \
# 0                 2Pac          All Eyez On Me
# 1                 2Pac          All Eyez On Me
# 2              50 Cent  Get Rich Or Die Tryin'
# 3            A$AP Ferg          Still Striving
# 4                A.C.O              Buscándote
# ...                ...                     ...
# 2066     sofia shizuko           chichiriviche
# 2067     Águila Sativa            Low Rider 64
# 2068  Ñengo El Quetzal                El Rikis
# 2069  Ñengo El Quetzal           Plakka Plakka
# 2070  Ñengo El Quetzal       Vengo de la Calle
#
#                                           track  saved  \
# 0                          Ambitionz Az A Ridah  False
# 1     Only God Can Judge Me (ft. Rappin' 4-Tay)  False
# 2                             Patiently Waiting  False
# 3                                    Plain Jane   True
# 4                                    Buscándote  False
# ...                                         ...    ...
# 2066                              chichiriviche   True
# 2067                               Low Rider 64  False
# 2068                                   El Rikis  False
# 2069                              Plakka Plakka  False
# 2070                          Vengo de la Calle  False
#
#                                        uri
# 0     spotify:track:20fBuVybkHgjF6vNhSMROD
# 1     spotify:track:2Z6I3youZAlfRvsyzJAGQA
# 2     spotify:track:3ORfa5ilEthp2U0TRcv7kv
# 3     spotify:track:4dVpf9jZjcORqGTLUaeYj9
# 4     spotify:track:5Qh1noyTdOz7d3GNTwwqJP
# ...                                    ...
# 2066  spotify:track:7MNtRrUXrsQwR10o3lvgDP
# 2067  spotify:track:7oCTo2ktHD7mX2knemZohF
# 2068  spotify:track:2VLpj3su9MbHqMWtxEqZhx
# 2069  spotify:track:1jzhpaWxMF1x4UtHrrERQW
# 2070  spotify:track:2UKfYR96zQkzHXwSbfyGDC
#
# [2033 rows x 5 columns]

# %%
working_df = data.set_index(["artist", "track"]).join(tracks_uris.set_index(["artist", "track"]), how = 'left').reset_index()

# %%
working_df.stb.missing()
# Out:
#           missing  total   percent
# album         906  10075  8.992556
# saved         906  10075  8.992556
# uri           906  10075  8.992556
# artist          0  10075  0.000000
# track           0  10075  0.000000
# endtime         0  10075  0.000000
# msplayed        0  10075  0.000000

# %%
working_df.duplicated(subset=['artist', 'album', 'track', 'endtime']).sum()
# Out:
# 120

# %%
working_df[working_df.duplicated(subset=['artist', 'album', 'track', 'endtime'])]
# Out:
#              artist         track           endtime  msplayed  \
# 152           Akwid    Mi Afición  2022-01-13 16:38    270293
# 252          Aleman  Hacia Arriba  2022-01-13 01:38    230341
# 255          Aleman  Hacia Arriba  2022-03-05 20:19    230341
# 258          Aleman  Hacia Arriba  2022-07-20 23:18    230341
# 261          Aleman  Hacia Arriba  2022-08-12 22:42    230341
# ...             ...           ...               ...       ...
# 8820  Santa Fe Klan        Socios  2022-11-08 17:02    243000
# 9991      Yoga Fire     Trap Talk  2022-02-10 22:36    210050
# 9993      Yoga Fire     Trap Talk  2022-04-09 03:05    210050
# 9995      Yoga Fire     Trap Talk  2022-05-19 19:32    105633
# 9997      Yoga Fire     Trap Talk  2022-08-12 20:20    134838
#
#                        album  saved                                   uri
# 152   KOMP 104.9 Radio Compa  False  spotify:track:5uA6YOi9X0wlW9HDtDlQH7
# 252          Pase de Abordar  False  spotify:track:7GEROcDGgLAZk2GEd1ivgo
# 255          Pase de Abordar  False  spotify:track:7GEROcDGgLAZk2GEd1ivgo
# 258          Pase de Abordar  False  spotify:track:7GEROcDGgLAZk2GEd1ivgo
# 261          Pase de Abordar  False  spotify:track:7GEROcDGgLAZk2GEd1ivgo
# ...                      ...    ...                                   ...
# 8820                  Socios   True  spotify:track:7d8TPVWQLeW5PKrAb76V3N
# 9991        Wavy Super Latin  False  spotify:track:0cfGMJlyI9kLCRqF4yv319
# 9993        Wavy Super Latin  False  spotify:track:0cfGMJlyI9kLCRqF4yv319
# 9995        Wavy Super Latin  False  spotify:track:0cfGMJlyI9kLCRqF4yv319
# 9997        Wavy Super Latin  False  spotify:track:0cfGMJlyI9kLCRqF4yv319
#
# [120 rows x 7 columns]

# %%
working_df.shape
# Out:
# (10075, 7)

# %%
working_df = working_df.drop_duplicates()

# %%
working_df
# Out:
#                      artist          track           endtime  msplayed  \
# 0      A Tribe Called Quest     Excursions  2022-01-28 21:59     41865
# 1                 A$AP Ferg     Plain Jane  2022-03-27 02:20    173600
# 2                 A$AP Ferg     Plain Jane  2022-11-29 01:31    173600
# 3                     A.C.O   De Madrugada  2022-01-21 02:55    220757
# 4                     A.C.O   De Madrugada  2022-07-18 15:48    220757
# ...                     ...            ...               ...       ...
# 10070         sofia shizuko  chichiriviche  2022-07-15 00:49    149000
# 10071         sofia shizuko  chichiriviche  2022-07-15 00:55    149000
# 10072         sofia shizuko  chichiriviche  2022-07-16 18:59     69525
# 10073         sofia shizuko  chichiriviche  2022-08-15 19:58    149000
# 10074      Ñengo El Quetzal  Plakka Plakka  2022-07-20 18:45    181054
#
#                 album  saved                                   uri
# 0                 NaN    NaN                                   NaN
# 1      Still Striving   True  spotify:track:4dVpf9jZjcORqGTLUaeYj9
# 2      Still Striving   True  spotify:track:4dVpf9jZjcORqGTLUaeYj9
# 3        De Madrugada   True  spotify:track:280QqgbMrLeMs6B80mIPG2
# 4        De Madrugada   True  spotify:track:280QqgbMrLeMs6B80mIPG2
# ...               ...    ...                                   ...
# 10070   chichiriviche   True  spotify:track:7MNtRrUXrsQwR10o3lvgDP
# 10071   chichiriviche   True  spotify:track:7MNtRrUXrsQwR10o3lvgDP
# 10072   chichiriviche   True  spotify:track:7MNtRrUXrsQwR10o3lvgDP
# 10073   chichiriviche   True  spotify:track:7MNtRrUXrsQwR10o3lvgDP
# 10074   Plakka Plakka  False  spotify:track:1jzhpaWxMF1x4UtHrrERQW
#
# [10075 rows x 7 columns]

# %% [markdown]
# ## Checkpoint

# %%
working_df.to_csv("processed/streaming_history_tracks.csv", encoding = 'utf-8', index = False)
podcast_data.to_csv("processed/streaming_history_pods.csv", encoding = 'utf-8', index = False)
